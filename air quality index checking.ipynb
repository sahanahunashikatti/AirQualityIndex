# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ShubhankarRawat/India---Air-Quality-Analysis/master/dataset.csv')
df
# Out:
# C:\Users\sahan\AppData\Local\Temp\ipykernel_4656\2547183107.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/ShubhankarRawat/India---Air-Quality-Analysis/master/dataset.csv')
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# ...

# %%
df.head(10)
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 5    152.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 6    150.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 7    151.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 8    152.0     April - M041990  Andhra Pradesh  Hyderabad    NaN
# 9    151.0       May - M051990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# ...

# %%
df.tail(10)
# Out:
#        stn_code sampling_date                        state  location  \
# 435732     SAMP     9/12/2015                  West Bengal  ULUBERIA
# 435733     SAMP    12/12/2015                  West Bengal  ULUBERIA
# 435734     SAMP      15-12-15                  West Bengal  ULUBERIA
# 435735     SAMP      18-12-15                  West Bengal  ULUBERIA
# 435736     SAMP      21-12-15                  West Bengal  ULUBERIA
# 435737     SAMP      24-12-15                  West Bengal  ULUBERIA
# 435738     SAMP      29-12-15                  West Bengal  ULUBERIA
# 435739      NaN           NaN  andaman-and-nicobar-islands       NaN
# 435740      NaN           NaN                  Lakshadweep       NaN
# 435741      NaN           NaN                      Tripura       NaN
#
#                                            agency   type   so2   no2   rspm  \
# 435732  West Bengal State Pollution Control Board  RIRUO  22.0  50.0  145.0
# ...

# %%
df.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
cat_cols=df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'location_monitoring_station', 'date'],
#       dtype='object')

# %%
num_cols=df.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['so2', 'no2', 'rspm', 'spm', 'pm2_5'], dtype='object')

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
df.shape
# Out:
# (435742, 13)

# %%
df[['so2','state']].groupby(["state"]).mean().sort_values(by='so2').head(20).plot.bar(color='b')
plt.show()

# %%
df[['no2','state']].groupby(["state"]).mean().sort_values(by='no2').plot.bar(color='g')
plt.show()

# %%
df[['spm','state']].groupby(["state"]).mean().sort_values(by='spm').plot.bar(color='b')
plt.show()

# %%
df[['rspm','state']].groupby(["state"]).mean().sort_values(by='rspm').plot.bar(color='r')
plt.show()

# %%
df[['pm2_5','state']].groupby(["state"]).mean().sort_values(by='pm2_5').plot.bar(color='y')
plt.show()

# %%
miss_val=(df.isnull().sum())
miss_val
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
data=df.drop(['stn_code','agency','sampling_date','location_monitoring_station'],axis='columns')
data
# Out:
#                               state   location  \
# 0                    Andhra Pradesh  Hyderabad
# 1                    Andhra Pradesh  Hyderabad
# 2                    Andhra Pradesh  Hyderabad
# 3                    Andhra Pradesh  Hyderabad
# 4                    Andhra Pradesh  Hyderabad
# ...                             ...        ...
# 435737                  West Bengal   ULUBERIA
# 435738                  West Bengal   ULUBERIA
# 435739  andaman-and-nicobar-islands        NaN
# 435740                  Lakshadweep        NaN
# 435741                      Tripura        NaN
#
#                                       type   so2   no2   rspm  spm  pm2_5  \
# 0       Residential, Rural and other Areas   4.8  17.4    NaN  NaN    NaN
# 1                          Industrial Area   3.1   7.0    NaN  NaN    NaN
# 2       Residential, Rural and other Areas   6.2  28.5    NaN  NaN    NaN
# 3       Residential, Rural and other Areas   6.3  14.7    NaN  NaN    NaN
# ...

# %%
percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending=False)

# %%
total = data.isnull().sum().sort_values(ascending=False) 
total
# Out:
# pm2_5       426428
# spm         237387
# rspm         40222
# so2          34646
# no2          16233
# type          5393
# date             7
# location         3
# state            0
# dtype: int64

# %%
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# %%
missing_data.head()
# Out:
#         Total    Percent
# pm2_5  426428  97.862497
# spm    237387  54.478797
# rspm    40222   9.230692
# so2     34646   7.951035
# no2     16233   3.725370

# %%
sns.barplot(x=missing_data.index, y=missing_data['Percent'])
plt.xlabel('Features', fontsize=20)
plt.ylabel('Percent of missing values', fontsize=20)
plt.title('Percent missing data by feature', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature')

# %%
data.groupby('state')[['spm','pm2_5','rspm','so2','no2']].mean()
# Out:
#                                     spm      pm2_5        rspm        so2  \
# state
# Andhra Pradesh               200.260378        NaN   78.182824   7.284845
# Arunachal Pradesh                   NaN        NaN   76.629213   3.179104
# Assam                        153.355386        NaN   93.724912   6.723263
# Bihar                        276.917416        NaN  123.705176  19.381476
# Chandigarh                   206.056150        NaN   96.587079   2.676986
# Chhattisgarh                 231.290969        NaN  126.472399  12.846609
# Dadra & Nagar Haveli         170.545024  30.511628   76.536530   8.939587
# Daman & Diu                  145.681416  27.886364   73.749431   8.192958
# Delhi                        399.402088  95.113208  196.639771   8.737273
# Goa                           67.254193  18.855612   61.212766   6.827913
# Gujarat                      191.567930  30.729696   98.244510  16.656343
# Haryana                      268.264804        NaN  149.860537  14.064957
# ...

# %%
def cap_data(data):
    for col in data.columns:
        print("\n\n capping the \n",col)
        if (((data[col].dtype)=='float64') | ((data[col].dtype)=='int64')):
            
            q1=data[col].quantile(0.25)
            q3=data[col].quantile(0.75)
            iqr=q3-q1
            lower,upper=(q1-(iqr*1.5)),(q3+(iqr*1.5))    
            print("q1=",q1,"q3=",q3,"iqr=",iqr,"lower=",lower,"upper=",upper) 
            data[col][data[col] <= lower] = lower
            data[col][data[col] >= upper] = upper
            print("\n",data[col][data[col] <= lower] )
            print("\n",data[col][data[col] >= upper] )
            
        else:
            data[col]=data[col]
    return data

final_df=cap_data(df)
# Out:
#  capping the
#  stn_code
#
#
#  capping the
#  sampling_date
#
#
#  capping the
#  state
#
#
#  capping the
#  location
#
#
#  capping the
#  agency
#
#
#  capping the
#  type
#
#
#  capping the
#  so2
# q1= 5.0 q3= 13.7 iqr= 8.7 lower= -8.049999999999999 upper= 26.75
# C:\Users\sahan\AppData\Local\Temp\ipykernel_4656\1631542058.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col][data[col] <= lower] = lower
# C:\Users\sahan\AppData\Local\Temp\ipykernel_4656\1631542058.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col][data[col] >= upper] = upper
# ...

# %%
grp_state = data.groupby('state')
def impute_mean_by_state(series):
    return series.fillna(series.mean())

# %%
data['rspm']=grp_state['rspm'].transform(impute_mean_by_state)  #fill value with mean value group by state
data['so2']=grp_state['so2'].transform(impute_mean_by_state)
data['no2']=grp_state['no2'].transform(impute_mean_by_state)
data['spm']=grp_state['spm'].transform(impute_mean_by_state)
data['pm2_5']=grp_state['pm2_5'].transform(impute_mean_by_state)

# %%
data.describe()
# Out:
#                  so2            no2           rspm            spm  \
# count  435739.000000  435739.000000  435739.000000  431671.000000
# mean       10.589141      25.663170     109.680907     215.198748
# std        10.863679      18.271145      72.519399     117.470157
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.800000      14.000000      59.000000     142.000000
# 50%         8.000000      21.800000      93.000000     205.255823
# 75%        13.000000      32.000000     142.016832     248.000000
# max       909.000000     876.000000    6307.033333    3380.000000
#
#                pm2_5
# count  123689.000000
# mean       48.317274
# std        21.455206
# min         3.000000
# 25%        30.729696
# 50%        42.204089
# 75%        64.890625
# max       504.000000

# %%
miss_val=(data.isnull().sum())
miss_val
# Out:
# state            0
# location         3
# type          5393
# so2              3
# no2              3
# rspm             3
# spm           4071
# pm2_5       312053
# date             7
# dtype: int64

# %%
def cal_SOi(so2):
    si=0
    if (so2<=40):
     si= so2*(50/40)
    elif (so2>40 and so2<=80):
     si= 50+(so2-40)*(50/40)
    elif (so2>80 and so2<=380):
     si= 100+(so2-80)*(100/300)
    elif (so2>380 and so2<=800):
     si= 200+(so2-380)*(100/420)
    elif (so2>800 and so2<=1600):
     si= 300+(so2-800)*(100/800)
    elif (so2>1600):
     si= 400+(so2-1600)*(100/800)
    return si
data['SOi']=data['so2'].apply(cal_SOi)
df1= data[['so2','SOi']]
df1.head()
# Out:
#    so2    SOi
# 0  4.8  6.000
# 1  3.1  3.875
# 2  6.2  7.750
# 3  6.3  7.875
# 4  4.7  5.875

# %%
def cal_Noi(no2):
    ni=0
    if(no2<=40):
     ni= no2*50/40
    elif(no2>40 and no2<=80):
     ni= 50+(no2-40)*(50/40)
    elif(no2>80 and no2<=180):
     ni= 100+(no2-80)*(100/100)
    elif(no2>180 and no2<=280):
     ni= 200+(no2-180)*(100/100)
    elif(no2>280 and no2<=400):
     ni= 300+(no2-280)*(100/120)
    else:
     ni= 400+(no2-400)*(100/120)
    return ni
data['Noi']=data['no2'].apply(cal_Noi)
df1= data[['no2','Noi']]
df1.head()
# Out:
#     no2     Noi
# 0  17.4  21.750
# 1   7.0   8.750
# 2  28.5  35.625
# 3  14.7  18.375
# 4   7.5   9.375

# %%
def cal_RSPMi(rspm):
    rpi=0
    if(rspm<=100):
     rpi = rspm
    elif(rspm>=101 and rspm<=150):
     rpi= 101+(rspm-101)*((200-101)/(150-101))
    elif(rspm>=151 and rspm<=350):
     ni= 201+(rspm-151)*((300-201)/(350-151))
    elif(rspm>=351 and rspm<=420):
     ni= 301+(rspm-351)*((400-301)/(420-351))
    elif(rspm>420):
     ni= 401+(rspm-420)*((500-401)/(420-351))
    return rpi
data['RSPMi']=data['rspm'].apply(cal_RSPMi)
df= data[['rspm','RSPMi']]
df.head()
# Out:
#         rspm      RSPMi
# 0  78.182824  78.182824
# 1  78.182824  78.182824
# 2  78.182824  78.182824
# 3  78.182824  78.182824
# 4  78.182824  78.182824

# %%
data.tail()
# Out:
#                               state  location   type   so2   no2   rspm  \
# 435737                  West Bengal  ULUBERIA  RIRUO  22.0  50.0  143.0
# 435738                  West Bengal  ULUBERIA  RIRUO  20.0  46.0  171.0
# 435739  andaman-and-nicobar-islands       NaN    NaN   NaN   NaN    NaN
# 435740                  Lakshadweep       NaN    NaN   NaN   NaN    NaN
# 435741                      Tripura       NaN    NaN   NaN   NaN    NaN
#
#                spm      pm2_5        date   SOi   Noi       RSPMi
# 435737  233.506524  64.890625  12/24/2015  27.5  62.5  185.857143
# 435738  233.506524  64.890625  12/29/2015  25.0  57.5    0.000000
# 435739         NaN        NaN         NaN   0.0   NaN    0.000000
# 435740         NaN        NaN         NaN   0.0   NaN    0.000000
# 435741         NaN        NaN         NaN   0.0   NaN    0.000000

# %%
def cal_SPMi(spm):
    spi=0
    if(spm<=50):
     spi=spm*50/50
    elif(spm>50 and spm<=100):
     spi=50+(spm-50)*(50/50)
    elif(spm>100 and spm<=250):
     spi= 100+(spm-100)*(100/150)
    elif(spm>250 and spm<=350):
     spi=200+(spm-250)*(100/100)
    elif(spm>350 and spm<=430):
     spi=300+(spm-350)*(100/80)
    else:
     spi=400+(spm-430)*(100/430)
    return spi
   
data['SPMi']=data['spm'].apply(cal_SPMi)
df1= data[['spm','SPMi']]
df1.head()
# Out:
#           spm        SPMi
# 0  200.260378  166.840252
# 1  200.260378  166.840252
# 2  200.260378  166.840252
# 3  200.260378  166.840252
# 4  200.260378  166.840252

# %%
def cal_pmi(pm2_5):
    pmi=0
    if(pm2_5<=50):
     pmi=pm2_5*(50/50)
    elif(pm2_5>50 and pm2_5<=100):
     pmi=50+(pm2_5-50)*(50/50)
    elif(pm2_5>100 and pm2_5<=250):
     pmi= 100+(pm2_5-100)*(100/150)
    elif(pm2_5>250 and pm2_5<=350):
     pmi=200+(pm2_5-250)*(100/100)
    elif(pm2_5>350 and pm2_5<=450):
     pmi=300+(pm2_5-350)*(100/100)
    else:
     pmi=400+(pm2_5-430)*(100/80)
    return pmi
data['PMi']=data['pm2_5'].apply(cal_pmi)
df1= data[['pm2_5','PMi']]
df1.head()
# Out:
#    pm2_5  PMi
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 3    NaN  NaN
# 4    NaN  NaN

# %%
type(data['PMi'])
# Out:
# pandas.core.series.Series

# %%
def cal_aqi(si,ni,rspmi,spmi):
    aqi=0
    if(si>ni and si>rspmi and si>spmi):
     aqi=si
    if(ni>si and ni>rspmi and ni>spmi ):
     aqi=ni
    if(rspmi>si and rspmi>ni and rspmi>spmi ):
     aqi=rspmi
    if(spmi>si and spmi>ni and spmi>rspmi):
     aqi=spmi
    return aqi

data['AQI']=data.apply(lambda x:cal_aqi(x['SOi'],x['Noi'],x['RSPMi'],x['SPMi']),axis=1)
df1= data[['state','SOi','Noi','RSPMi','SPMi','AQI']]
df1.head()
# Out:
#             state    SOi     Noi      RSPMi        SPMi         AQI
# 0  Andhra Pradesh  6.000  21.750  78.182824  166.840252  166.840252
# 1  Andhra Pradesh  3.875   8.750  78.182824  166.840252  166.840252
# 2  Andhra Pradesh  7.750  35.625  78.182824  166.840252  166.840252
# 3  Andhra Pradesh  7.875  18.375  78.182824  166.840252  166.840252
# 4  Andhra Pradesh  5.875   9.375  78.182824  166.840252  166.840252

# %%
def AQI_Range(x):
    if x<=50:
        return "Good"
    elif x>50 and x<=100:
        return "Moderate"
    elif x>100 and x<=200:
        return "Poor"
    elif x>200 and x<=300:
        return "Unhealthy"
    elif x>300 and x<=400:
        return "Very unhealthy"
    elif x>400:
        return "Hazardous"

data['AQI_Range'] = data['AQI'] .apply(AQI_Range)
data.head()
# Out:
#             state   location                                type  so2   no2  \
# 0  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  4.8  17.4
# 1  Andhra Pradesh  Hyderabad                     Industrial Area  3.1   7.0
# 2  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.2  28.5
# 3  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.3  14.7
# 4  Andhra Pradesh  Hyderabad                     Industrial Area  4.7   7.5
#
#         rspm         spm  pm2_5      date    SOi     Noi      RSPMi  \
# 0  78.182824  200.260378    NaN  2/1/1990  6.000  21.750  78.182824
# 1  78.182824  200.260378    NaN  2/1/1990  3.875   8.750  78.182824
# 2  78.182824  200.260378    NaN  2/1/1990  7.750  35.625  78.182824
# 3  78.182824  200.260378    NaN  3/1/1990  7.875  18.375  78.182824
# 4  78.182824  200.260378    NaN  3/1/1990  5.875   9.375  78.182824
#
#          SPMi  PMi         AQI AQI_Range
# 0  166.840252  NaN  166.840252      Poor
# ...

# %%
data.tail()
# Out:
#               state  location   type   so2   no2   rspm         spm  \
# 435734  West Bengal  ULUBERIA  RIRUO  20.0  44.0  148.0  233.506524
# 435735  West Bengal  ULUBERIA  RIRUO  17.0  44.0  131.0  233.506524
# 435736  West Bengal  ULUBERIA  RIRUO  18.0  45.0  140.0  233.506524
# 435737  West Bengal  ULUBERIA  RIRUO  22.0  50.0  143.0  233.506524
# 435738  West Bengal  ULUBERIA  RIRUO  20.0  46.0  171.0  233.506524
#
#             pm2_5        date    SOi    Noi       RSPMi        SPMi  \
# 435734  64.890625  12/15/2015  25.00  55.00  195.959184  189.004349
# 435735  64.890625  12/18/2015  21.25  55.00  161.612245  189.004349
# 435736  64.890625  12/21/2015  22.50  56.25  179.795918  189.004349
# 435737  64.890625  12/24/2015  27.50  62.50  185.857143  189.004349
# 435738  64.890625  12/29/2015  25.00  57.50    0.000000  189.004349
#
#               PMi         AQI AQI_Range
# 435734  64.890625  195.959184      Poor
# 435735  64.890625  189.004349      Poor
# ...

# %%
data=data.dropna(subset=['spm']) #spm

# %%
data=data.dropna(subset=['pm2_5']) #spm

# %%
miss_val=(data.isnull().sum())
miss_val
# Out:
# state           0
# location        0
# type         1925
# so2             0
# no2             0
# rspm            0
# spm             0
# pm2_5           0
# date            1
# SOi             0
# Noi             0
# RSPMi           0
# SPMi            0
# PMi             0
# AQI             0
# AQI_Range       0
# dtype: int64

# %%
data.shape
# Out:
# (119711, 16)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['SOi','Noi','RSPMi','SPMi']]
y = data['AQI_Range']
y.head()
# Out:
# 64445    Moderate
# 64446    Moderate
# 64447    Moderate
# 64448    Moderate
# 64449    Moderate
# Name: AQI_Range, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33,random_state=42)

# %%
x_train.head()
# Out:
#               SOi     Noi       RSPMi        SPMi
# 360294   5.000000  30.000   23.000000  117.819376
# 278096   7.250000  13.875  157.571429  212.000000
# 277941   3.625000  32.875   72.000000  126.666667
# 269637  22.875000  35.750   83.619824  136.666667
# 272765   6.594842  15.875   80.000000  150.666667

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.predict([[6.000,21.750,78.182824,166.840252]])
# Out:
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Poor'], dtype=object)

# %%
model.predict([[2.059,8.94,102,256]])
# Out:
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Unhealthy'], dtype=object)

# %%
model.predict([[2,5.8,17,36]])
# Out:
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Good'], dtype=object)

# %%
model.predict([[10,16,156,372.66]])
# Out:
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Very unhealthy'], dtype=object)

# %%
model.score(x_test,y_test)*100       #accuracy of the model is 99.98%
# Out:
# 99.982280723959

# %%
import pickle

# %%
with open('air_quality_index','wb') as f:
    pickle.dump(model,f)

# %%
with open('air_quality_index','rb') as f:
    mp=pickle.load(f)

# %%
mp.predict([[2.059,8.94,102,256]])
# Out:
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Unhealthy'], dtype=object)
